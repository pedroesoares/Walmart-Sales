# %% [markdown]
# # 1.0 Imports

# %%
import pandas              as pd
import numpy               as np
import seaborn             as sns
import matplotlib.pyplot   as plt
import os
import datetime
import xgboost             as xgb

from boruta                  import BorutaPy
from scipy                   import stats as ss
from sklearn.preprocessing   import RobustScaler, MinMaxScaler, LabelEncoder
from sklearn.ensemble        import RandomForestRegressor
from sklearn.metrics         import mean_absolute_error, mean_squared_error
from sklearn.linear_model    import LinearRegression, Lasso
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

import warnings
warnings.filterwarnings('ignore')

# %%
plt.style.use('bmh')
plt.rcParams['figure.figsize'] = [30, 20]
plt.rcParams['font.size'] = 25

# %% [markdown]
# # 2.0 Statitistical analysis

# %%
#Descritivo das variaveis
#We will study the sales data of one of the largest retailers in the world. Let's figure out what factors influence its revenue. Can factors such as air temperature and fuel cost influence the success of a huge company along with the purchasing power index and seasonal discounts? And how does machine learning minimize costs and increase economic impact?

#The data contains the following columns:

# - Store: Store number
# - Date: Sales week start date
# - Weekly_Sales: Sales
# - Holiday_Flag: Mark on the presence or absence of a holiday
# - Temperature: Air temperature in the region
# - Fuel_Price: Fuel cost in the region
# - CPI: Consumer price index
# - Unemployment: Unemployment rate

# %%
# Opening CSV
df = pd.read_csv('https://raw.githubusercontent.com/pedroesoares/Walmart-Sales/main/Walmart_sales.csv')
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
#Descrição estatística dos dados
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
#Df Types and Df is na
df.sum().isna()
# Out:
# Store           False
# Date            False
# Weekly_Sales    False
# Holiday_Flag    False
# Temperature     False
# Fuel_Price      False
# CPI             False
# Unemployment    False
# dtype: bool

# %%
df.dtypes
# Out:
# Store             int64
# Date             object
# Weekly_Sales    float64
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# dtype: object

# %%
num_attributes = df.select_dtypes(include=['int64', 'float64'])
num_attributes.drop('Store', axis=1, inplace=True)

# %%
# Dispersion - desvio padrão, min, max, range, skew and kurtosis

d1 = pd.DataFrame( num_attributes.apply(np.std)).T
d2 = pd.DataFrame( num_attributes.apply( min ) ).T
d3 = pd.DataFrame( num_attributes.apply( max ) ).T
d4 = pd.DataFrame( num_attributes.apply(lambda x: x.max() - x.min())).T
d5 = pd.DataFrame( num_attributes.apply(lambda x: x.skew())).T
d6 = pd.DataFrame( num_attributes.apply(lambda x: x.kurtosis())).T

#Concatenar dados

metricas = pd.concat( [d2, d3, d4, d1, d5, d6] ).T.reset_index()
metricas.columns = ['Attributes', 'Min', 'Max', 'Median', 'std', 'Skew', 'Kurtosis']

# %%
metricas
# Out:
#      Attributes         Min           Max        Median            std  \
# 0  Weekly_Sales  209986.250  3.818686e+06  3.608700e+06  564322.769020
# 1  Holiday_Flag       0.000  1.000000e+00  1.000000e+00       0.255029
# 2   Temperature      -2.060  1.001400e+02  1.022000e+02      18.443500
# 3    Fuel_Price       2.472  4.468000e+00  1.996000e+00       0.458984
# 4           CPI     126.064  2.272328e+02  1.011688e+02      39.353654
# 5  Unemployment       3.879  1.431300e+01  1.043400e+01       1.875739
#
#        Skew  Kurtosis
# 0  0.668362  0.053141
# 1  3.373499  9.383410
# 2 -0.336768 -0.612801
# 3 -0.096158 -1.177378
# 4  0.063492 -1.839813
# 5  1.188144  2.639712

# %%
df.rename(columns={'Weekly_Sales':'Sales'},inplace=True)

# %% [markdown]
# # 3.0 Exploratory analisys

# %% [markdown]
# ## Hypothesis
# 1. Stores should sell more in Holidays rather than normal days / weeks.
# 2. Sales should be higher when Unemployment rate is lower.
# 3. Stores where fuel price is lower should have higher sales.
# 4. Diferent Stores should have diferent types of sales.
# 5. Moments of higher CPI (Consumer Price Index) should be lower on sales.

# %%
#sns.displot(df['Weekly_Sales']);
#sns.displot(df['Temperature']);
#sns.displot(df['Fuel_Price']);
#sns.displot(df['CPI']);
sns.displot(df['Unemployment']);

# %%
aux1 = df[(df['Sales'] > 0)]
sns.boxplot(x='Holiday_Flag', y='Sales', data=aux1 )
# Out:
# <Axes: xlabel='Holiday_Flag', ylabel='Sales'>

# %%
sns.lineplot(data=aux1, x='Date', y='Sales')
# Out:
# <Axes: xlabel='Date', ylabel='Sales'>

# %%
df
# Out:
#       Store        Date       Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010  1643690.90             0        42.31       2.572
# 1         1  12-02-2010  1641957.44             1        38.51       2.548
# 2         1  19-02-2010  1611968.17             0        39.93       2.514
# 3         1  26-02-2010  1409727.59             0        46.63       2.561
# 4         1  05-03-2010  1554806.68             0        46.50       2.625
# ...     ...         ...         ...           ...          ...         ...
# 6430     45  28-09-2012   713173.95             0        64.88       3.997
# 6431     45  05-10-2012   733455.07             0        64.89       3.985
# 6432     45  12-10-2012   734464.36             0        54.47       4.000
# 6433     45  19-10-2012   718125.53             0        56.47       3.969
# 6434     45  26-10-2012   760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
df2 = df
df2['Date'] = pd.to_datetime(df2['Date'], format = '%d-%m-%Y')

# %%
#Extrair informações de Datas
#Ano
df2['Year'] = df2['Date'].dt.year

#Mês
df2['Month'] = df2['Date'].dt.month

#Semana
#df2['Week'] = df2['Date'].dt.weekofyear

#Dia
df2['Day'] = df2['Date'].dt.day

# %%
num_attributes = df2[['Sales','Temperature','Fuel_Price','CPI','Unemployment']]
cat_attributes = df2[['Store','Date','Holiday_Flag','Year','Month','Day']]

# %%
num_attributes.hist(bins=25);

# %%
#Lojas vendem mais em Feriados do que dias normais

# %%
plt.subplot(2,1,1)
#df2[df2['Store'] == 11]
sns.barplot(x='Store', y='Unemployment', data= df)

plt.subplot(2,1,2)
#df2[df2['Store'] == 11]
sns.barplot(x='Store', y='CPI', data= df)
# Out:
# <Axes: xlabel='Store', ylabel='CPI'>

# %%
corr = num_attributes.corr(method='pearson')
sns.heatmap(corr, annot= True);

# %% [markdown]
# ## 4.0 Pre processing

# %% [markdown]
# ### 4.1 Scalling

# %%
mms = MinMaxScaler()

# %%
df2['Temperature'] = mms.fit_transform(df2[['Temperature']].values)
df2['Fuel_Price'] = mms.fit_transform(df2[['Fuel_Price']].values)
df2['CPI'] = mms.fit_transform(df2[['CPI']].values)
df2['Unemployment'] = mms.fit_transform(df2[['Unemployment']].values)

# %%
#df2['Sales 2'] = np.log1p(df2['Sales'])

# %%
sns.distplot(df2['Sales']);

# %%
df = df2

# %%
#df2['Sales'] = np.log1p(df2['Sales'])
#df2.drop(columns='Sales 2', inplace =True)
df2
# Out:
#       Store       Date       Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05  1643690.90             0     0.434149    0.050100
# 1         1 2010-02-12  1641957.44             1     0.396967    0.038076
# 2         1 2010-02-19  1611968.17             0     0.410861    0.021042
# 3         1 2010-02-26  1409727.59             0     0.476419    0.044589
# 4         1 2010-03-05  1554806.68             0     0.475147    0.076653
# ...     ...        ...         ...           ...          ...         ...
# 6430     45 2012-09-28   713173.95             0     0.654990    0.764028
# 6431     45 2012-10-05   733455.07             0     0.655088    0.758016
# 6432     45 2012-10-12   734464.36             0     0.553131    0.765531
# 6433     45 2012-10-19   718125.53             0     0.572701    0.750000
# 6434     45 2012-10-26   760281.43             0     0.595988    0.706413
#
#            CPI  Unemployment  Year  Month  Day
# 0     0.840500      0.405118  2010      2    5
# 1     0.841941      0.405118  2010      2   12
# 2     0.842405      0.405118  2010      2   19
# 3     0.842707      0.405118  2010      2   26
# 4     0.843008      0.405118  2010      3    5
# ...        ...           ...   ...    ...  ...
# 6430  0.651876      0.460514  2012      9   28
# 6431  0.653427      0.458884  2012     10    5
# 6432  0.654977      0.458884  2012     10   12
# 6433  0.655013      0.458884  2012     10   19
# 6434  0.654796      0.458884  2012     10   26
#
# [6435 rows x 11 columns]

# %% [markdown]
# ## 5.0 Feature Selection

# %%
# first lets split our datasets into Train and Test
MinDate = df2['Date'][0]
MaxDate = df2['Date'][6434]

#df2['Date'].sort_values(ascending=False)[6434]
#df2[['Sales']] = np.expm1(df2[['Sales']])

split = MaxDate - MinDate
splitDate = split*0.75+MinDate

xtrain = df2[df2['Date']<splitDate]
ytrain = xtrain['Sales']

xtest = df2[df2['Date']>=splitDate]
ytest = xtest['Sales']

xtrain_n = xtrain.drop(columns=['Date','Sales'])

datas = df2[df2['Date']>=splitDate]

# %%
sns.lineplot(data=df2, x='Date',y='Sales')
# Out:
# <Axes: xlabel='Date', ylabel='Sales'>

# %%
df2['Sales 2'] = np.expm1(df2['Sales'])

# %%
rf = RandomForestRegressor(n_jobs=-1)

xtrain_n = xtrain_n.values
ytrain = ytrain.values.ravel()

# %%
#boruta = BorutaPy(rf, n_estimators='auto',verbose=2,random_state=42).fit(xtrain_n, ytrain)

# %%
#boruta.support_.tolist()
xtrain_boruta = xtrain.drop(columns=['Date','Sales'])

# %%
#xtrain_boruta.columns[boruta.support_]

# %%
#Segundo o Boruta, utilizando o metodo de Random Forest, identificamos que as features que fazem sentido para o modelo são:
cols_boruta = ['Store','Temperature','Fuel_Price','CPI','Unemployment']

# %%
def mean_absolute_percentage_error(y, yhat):
    return np.mean(np.abs((y - yhat)/y))
    

def ml_error( model_name, y, yhat):
    mae = mean_absolute_error(y, yhat) 
    mape = mean_absolute_percentage_error( y, yhat)
    rmse = np.sqrt(mean_squared_error( y, yhat)) 
    
    return pd.DataFrame({'Model Name': model_name, 'MAE': mae, 'MAPE': mape, 'RMSE': rmse}, index=[0])

# %%
xtrain = xtrain[cols_boruta]
xtest=xtest[cols_boruta]

# %% [markdown]
# ## 6.0 Random Forest Regressor

# %%
# Model
rf = RandomForestRegressor( n_estimators=100, n_jobs=-1, random_state=42).fit(xtrain, ytrain)

# Prediction
yhat_rf = rf.predict(xtest)

# Performance
rf_result = ml_error('Random Forest Regressor', (ytest),(yhat_rf))
rf_result
# Out:
#                 Model Name            MAE      MAPE           RMSE
# 0  Random Forest Regressor  127777.596958  0.140093  234441.241117

# %%
xtest.insert(5, "Predictions", yhat_rf)
xtest['Date'] = datas['Date']
xtest['Sales'] = ytest
xtest
# Out:
#       Store  Temperature  Fuel_Price       CPI  Unemployment   Predictions  \
# 107       1     0.580333    0.542585  0.934803      0.332471  1.690480e+06
# 108       1     0.616634    0.580160  0.936890      0.332471  1.700562e+06
# 109       1     0.595108    0.599699  0.938977      0.332471  1.693791e+06
# 110       1     0.653620    0.632265  0.940486      0.332471  1.675282e+06
# 111       1     0.665264    0.658818  0.941223      0.332471  1.648012e+06
# ...     ...          ...         ...       ...           ...           ...
# 6430     45     0.654990    0.764028  0.651876      0.460514  8.079198e+05
# 6431     45     0.655088    0.758016  0.653427      0.458884  8.079198e+05
# 6432     45     0.553131    0.765531  0.654977      0.458884  8.128461e+05
# 6433     45     0.572701    0.750000  0.655013      0.458884  8.128461e+05
# 6434     45     0.595988    0.706413  0.654796      0.458884  8.123619e+05
#
#            Date       Sales
# 107  2012-02-24  1539387.83
# 108  2012-03-02  1688420.76
# 109  2012-03-09  1675431.16
# 110  2012-03-16  1677472.78
# 111  2012-03-23  1511068.07
# ...         ...         ...
# 6430 2012-09-28   713173.95
# 6431 2012-10-05   733455.07
# 6432 2012-10-12   734464.36
# 6433 2012-10-19   718125.53
# 6434 2012-10-26   760281.43
#
# [1620 rows x 8 columns]

# %%
sns.lineplot(data=xtest, x='Date', y='Sales')
sns.lineplot(data=xtest, x='Date', y='Predictions')
# Out:
# <Axes: xlabel='Date', ylabel='Sales'>

# %% [markdown]
# ## 7.0 XGBoost Model

# %%
xtrain = xtrain[cols_boruta]
xtest=xtest[cols_boruta]

# %%
yhat_xgb = xgb.XGBRegressor(n_estimators=1000, max_depth=10,eta=0.1,subsample=0.7,colsample_bytree=1)
y_tnn_xgb = xgb.XGBRegressor(n_estimators=975, max_depth=50,eta=00.05,subsample=0.2,colsample_bytree=0.9)

# %%
yhat_xgb.fit(xtrain,ytrain)
y_tnn_xgb.fit(xtrain,ytrain)

yhat_xgb.score(xtrain,ytrain)
y_tnn_xgb.score(xtrain,ytrain)
# Out:
# 0.9991989214310517

# %%
ypred = yhat_xgb.predict(xtest)
ypred_tnn = y_tnn_xgb.predict(xtest)

# %%
xtest['Predictions_XGB'] = (ypred)
xtest['Sales'] = (ytest)

# %%
sns.scatterplot(data = xtest, x='Sales', y='Predictions_XGB')
# Out:
# <Axes: xlabel='Sales', ylabel='Predictions_XGB'>

# %%
xtest
# Out:
#       Store  Temperature  Fuel_Price       CPI  Unemployment  Predictions_XGB  \
# 107       1     0.580333    0.542585  0.934803      0.332471      1647906.875
# 108       1     0.616634    0.580160  0.936890      0.332471      1634169.500
# 109       1     0.595108    0.599699  0.938977      0.332471      1607573.000
# 110       1     0.653620    0.632265  0.940486      0.332471      1551010.000
# 111       1     0.665264    0.658818  0.941223      0.332471      1529196.250
# ...     ...          ...         ...       ...           ...              ...
# 6430     45     0.654990    0.764028  0.651876      0.460514       808624.875
# 6431     45     0.655088    0.758016  0.653427      0.458884       825364.750
# 6432     45     0.553131    0.765531  0.654977      0.458884       834636.750
# 6433     45     0.572701    0.750000  0.655013      0.458884       826385.000
# 6434     45     0.595988    0.706413  0.654796      0.458884       856923.000
#
#            Sales
# 107   1539387.83
# 108   1688420.76
# 109   1675431.16
# 110   1677472.78
# 111   1511068.07
# ...          ...
# 6430   713173.95
# 6431   733455.07
# 6432   734464.36
# 6433   718125.53
# 6434   760281.43
#
# [1620 rows x 7 columns]

# %%
xtest['Date'] = datas['Date']
sns.lineplot(data=xtest, x='Date', y='Sales')
sns.lineplot(data=xtest, x='Date', y='Predictions_XGB')
# Out:
# <Axes: xlabel='Date', ylabel='Sales'>

# %%
xgb_result = ml_error('XGBRegressor', (ytest), (ypred))
xgb_result
# Out:
#      Model Name            MAE      MAPE           RMSE
# 0  XGBRegressor  119675.026323  0.136399  177380.477213

# %%
# Models Compare
modelling_result = pd.concat([rf_result, xgb_result])
modelling_result.sort_values('RMSE')
# Out:
#                 Model Name            MAE      MAPE           RMSE
# 0             XGBRegressor  119675.026323  0.136399  177380.477213
# 0  Random Forest Regressor  127777.596958  0.140093  234441.241117

# %%
from sklearn.model_selection import KFold


#scores = KFold(n_splits=5, random_state=42)

# %% [markdown]
# ## 8.0 Params Hyper Tunning

# %%
param={
    "n_estimators" : np.arange(800,1200,25),
    "max_depth" : np.arange(0,80,5),
    "eta" : np.arange(0,0.8,0.05),
    "subsample" : np.arange(0,0.8,0.05),
    "colsample_bytree" : np.arange(0.2,1,0.05)
}

# %%
model = xgb.XGBRegressor()
#random_search = RandomizedSearchCV(model, param_distributions=param, n_iter = 7, scoring = 'roc_auc',n_jobs = -1,cv=5,verbose=3)

# %%
#random_search.best_params_

# %% [markdown]
# ## Error interpretation

# %%
xtest['% Diff'] = ((xtest['Sales'] - xtest['Predictions_XGB'])/xtest['Sales'])*100

# %%
sns.lineplot(data=xtest, x='Date', y='% Diff')
# Out:
# <Axes: xlabel='Date', ylabel='% Diff'>

# %%
xgb_result['MAE']
# Out:
# 0    119675.026323
# Name: MAE, dtype: float64

# %%
df3 = xtest
df3 = df3[['Store','Sales','Predictions_XGB']]

# MAE e MAPE
df_aux1 = df3[['Store', 'Sales', 'Predictions_XGB']].groupby('Store').apply(lambda x: mean_absolute_error(x['Sales'], x['Predictions_XGB'])).reset_index().rename(columns={0:'MAE'})
df_aux2 = df3[['Store', 'Sales', 'Predictions_XGB']].groupby('Store').apply(lambda x: mean_absolute_percentage_error(x['Sales'], x['Predictions_XGB'])).reset_index().rename(columns={0:'MAPE'})

df_aux3 = pd.merge(df_aux1,df_aux2, how='inner', on='Store')
df3 = pd.merge(df3, df_aux3, how='inner', on='Store')

# Scenarios
df3['worst_scenario'] = df3['Predictions_XGB'] - df3['MAE']
df3['best_scenario'] = df3['Predictions_XGB'] + df3['MAE']

# %%
df3['% Diff'] = ((df3['Sales'] - df3['Predictions_XGB'])/df3['Sales'])*100
df3 = df3.drop(columns=['MAE','MAPE'])
df3
# Out:
#       Store       Sales  Predictions_XGB  worst_scenario  best_scenario  \
# 0         1  1539387.83      1647906.875    1.571557e+06   1.724257e+06
# 1         1  1688420.76      1634169.500    1.557820e+06   1.710519e+06
# 2         1  1675431.16      1607573.000    1.531223e+06   1.683923e+06
# 3         1  1677472.78      1551010.000    1.474660e+06   1.627360e+06
# 4         1  1511068.07      1529196.250    1.452847e+06   1.605546e+06
# ...     ...         ...              ...             ...            ...
# 1615     45   713173.95       808624.875    7.451997e+05   8.720500e+05
# 1616     45   733455.07       825364.750    7.619396e+05   8.887899e+05
# 1617     45   734464.36       834636.750    7.712116e+05   8.980619e+05
# 1618     45   718125.53       826385.000    7.629598e+05   8.898102e+05
# 1619     45   760281.43       856923.000    7.934978e+05   9.203482e+05
#
#          % Diff
# 0     -7.049493
# 1      3.213136
# 2      4.050191
# 3      7.538887
# 4     -1.199693
# ...         ...
# 1615 -13.383961
# 1616 -12.531058
# 1617 -13.638836
# 1618 -15.075285
# 1619 -12.711289
#
# [1620 rows x 6 columns]

# %%
df4 = df3[['Sales','Predictions_XGB','worst_scenario', 'best_scenario']].apply(lambda x: np.sum(x), axis=0).reset_index().rename(columns= {'index': 'Scenario', 0: 'Values'})
df4['Values'] = df4['Values'].map('R${:,.2f}'.format)
df4
# Out:
#           Scenario              Values
# 0            Sales  R$1,684,946,314.72
# 1  Predictions_XGB  R$1,701,283,456.00
# 2   worst_scenario  R$1,507,409,895.01
# 3    best_scenario  R$1,895,156,980.30

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# Supondo que df3 tem: 'Store', 'Date', 'Sales', 'Predictions_XGB'

# Criar coluna de erro absoluto e percentual
xtest['abs_error'] = abs(xtest['Sales'] - xtest['Predictions_XGB'])
xtest['perc_error'] = (xtest['abs_error'] / xtest['Sales']) * 100

# Média por semana (todas as lojas juntas)
mae_weekly = xtest.groupby('Date')['abs_error'].mean().reset_index().rename(columns={'abs_error':'MAE'})
mape_weekly = xtest.groupby('Date')['perc_error'].mean().reset_index().rename(columns={'perc_error':'MAPE'})

# Juntando as duas métricas por semana
weekly_summary = pd.merge(mae_weekly, mape_weekly, on='Date')
weekly_summary.head()



# Agrupar por Store e Date
store_weekly_summary = xtest.groupby(['Store','Date']).agg(
    MAE=('abs_error','mean'),
    MAPE=('perc_error','mean')
).reset_index()

store_weekly_summary.head()



# Média do MAE semanal (todas lojas)
mean_mae_weekly = weekly_summary['MAE'].mean()
mean_mape_weekly = weekly_summary['MAPE'].mean()
print(f"Average weekly MAE (all stores): {mean_mae_weekly:.2f} units")
print(f"Average weekly MAPE (all stores): {mean_mape_weekly:.2f}%")
# Out:
# Average weekly MAE (all stores): 119675.03 units
# Average weekly MAPE (all stores): 13.64%
